# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv ('datos.csv', sep=',' ,quotechar='"')

# %%
x = df.head(11)

# %%
x
# Out:
#     0.41  0.08  0.57  0.76  0.66  0.49   0.9   0.6   0.4  0.31  Intervalo  \
# 0   0.05  0.75  0.97  0.38  0.60  0.31  0.53  0.18  0.93  0.19        0.0
# 1   0.92  0.06  0.46  0.83  0.60  0.37  0.01  0.23  0.29  0.51        0.1
# 2   0.81  0.87  0.81  0.19  0.05  0.12  0.99  0.88  0.96  0.53        0.2
# 3   0.92  0.83  0.26  0.63  0.52  0.12  0.12  0.68  0.61  0.82        0.3
# 4   0.34  0.17  0.37  0.90  0.58  0.89  0.31  0.71  0.95  0.97        0.4
# 5   0.05  0.31  0.12  0.30  0.18  0.09  0.21  0.95  0.54  0.96        0.5
# 6   0.61  0.17  0.17  0.18  0.57  0.76  0.72  0.01  0.44  0.38        0.6
# 7   0.66  0.78  0.45  0.12  0.95  0.38  0.52  0.27  0.15  0.40        0.7
# 8   0.25  0.86  0.10  0.34  0.80  0.02  0.16  0.71  0.53  0.69        0.8
# 9   0.08   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN        0.9
# 10  0.75   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN        NaN
#
#     Unnamed: 11    Fo    Fe  chi²
# 0           0.1  10.0  10.0   0.0
# 1           0.2  15.0  10.0   2.5
# 2           0.3   7.0  10.0   0.9
# 3           0.4  13.0  10.0   0.9
# 4           0.5   5.0  10.0   2.5
# 5           0.6  13.0  10.0   0.9
# 6           0.7   7.0  10.0   0.9
# 7           0.8   8.0  10.0   0.4
# 8           0.9  11.0  10.0   0.1
# 9           1.0  11.0  10.0   0.1
# 10          NaN   NaN   NaN   NaN

# %%
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.15, .85)})
 

sns.boxplot(df["Fo"], ax=ax_box)
sns.distplot(df["Fo"], ax=ax_hist)
 

ax_box.set(yticks=[])
sns.despine(ax=ax_hist)
sns.despine(ax=ax_box, left=True)
